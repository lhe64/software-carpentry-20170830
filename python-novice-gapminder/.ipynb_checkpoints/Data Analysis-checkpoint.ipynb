# %%
pwd
# Out:
# 'C:\\Users\\linhe\\Desktop\\python-novice-gapminder'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FC6D-7E6C
#
#  Directory of C:\Users\linhe\Desktop\python-novice-gapminder
#
# 08/31/2017  02:11 PM    <DIR>          .
# 08/31/2017  02:11 PM    <DIR>          ..
# 08/31/2017  02:09 PM    <DIR>          .ipynb_checkpoints
# 08/31/2017  02:08 PM    <DIR>          data
# 08/31/2017  02:11 PM               932 Untitled.ipynb
#                1 File(s)            932 bytes
#                4 Dir(s)  56,912,388,096 bytes free

# %%
import math

# %%
-6/3
# Out:
# -2.0

# %%
math.cos(math.pi
        )
# Out:
# -1.0

# %%
1. print("sin(pi/2) =",sin(pi/2))
2. print("sin(pi/2) =",m.sin(m.pi/2))
3. print("sin(pi/2) =",math.sin(math.pi/2))
# Out:
#   File "<ipython-input-6-abc1d928a2b8>", line 1
#     1. print("sin(pi/2) =",sin(pi/2))
#            ^
# SyntaxError: invalid syntax

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
m.sin(m.pi/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6c66e595eb4d> in <module>()
# ----> 1 m.sin(m.pi/2)
#
# NameError: name 'm' is not defined

# %%
sin(pi/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-01f4187e1d05> in <module>()
# ----> 1 sin(pi/2)
#
# NameError: name 'sin' is not defined

# %%
 print("sin(pi/2) =",sin(pi/2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-296eeec78084> in <module>()
# ----> 1 print("sin(pi/2) =",sin(pi/2))
#
# NameError: name 'sin' is not defined

# %%
from math import *

# %%
 print("sin(pi/2) =",sin(pi/2))
# Out:
# sin(pi/2) = 1.0

# %%
import math as m
print("sin(pi/2) =",m.sin(m.pi/2))
# Out:
# sin(pi/2) = 1.0

# %%
sin(pi/2)
# Out:
# 1.0

# %%
import pandas

# %%
oceania=pandas.read_csv('data/gapminder_gdp_oceania.csv', index_col= 'country')

# %%
type (oceania)
# Out:
# pandas.core.frame.DataFrame

# %%
print (oceania)
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
print(oceania.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(oceania.index)
# Out:
# Index(['Australia', 'New Zealand'], dtype='object', name='country')

# %%
coeania.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-88af965fe1e6> in <module>()
# ----> 1 coeania.T
#
# NameError: name 'coeania' is not defined

# %%
oceania.T
oceania.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FC6D-7E6C
#
#  Directory of C:\Users\linhe\Desktop\python-novice-gapminder
#
# 08/31/2017  02:35 PM    <DIR>          .
# 08/31/2017  02:35 PM    <DIR>          ..
# 08/31/2017  02:18 PM    <DIR>          .ipynb_checkpoints
# 08/31/2017  02:08 PM    <DIR>          data
# 08/31/2017  02:35 PM            19,321 Data Analysis.ipynb
#                1 File(s)         19,321 bytes
#                4 Dir(s)  56,910,299,136 bytes free

# %%
ls Data
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FC6D-7E6C
#
#  Directory of C:\Users\linhe\Desktop\python-novice-gapminder\Data
#
# 08/31/2017  02:08 PM    <DIR>          .
# 08/31/2017  02:08 PM    <DIR>          ..
# 08/28/2016  12:29 PM            49,082 gapminder_all.csv
# 08/28/2016  12:29 PM             8,095 gapminder_gdp_africa.csv
# 08/28/2016  12:29 PM             4,230 gapminder_gdp_americas.csv
# 08/28/2016  12:29 PM             5,103 gapminder_gdp_asia.csv
# 08/28/2016  12:29 PM             4,750 gapminder_gdp_europe.csv
# 08/28/2016  12:29 PM               494 gapminder_gdp_oceania.csv
#                6 File(s)         71,754 bytes
#                2 Dir(s)  56,910,299,136 bytes free

# %%
europe=pandas.read_csv("Data/gapminder_gdp_europe.csv",index_col="country")

# %%
europe.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       30.000000       30.000000       30.000000       30.000000
# mean      5661.057435     6963.012816     8365.486814    10143.823757
# std       3114.060493     3677.950146     4199.193906     4724.983889
# min        973.533195     1353.989176     1709.683679     2172.352423
# 25%       3241.132406     4394.874315     5373.536612     6657.939047
# 50%       5142.469716     6066.721495     7515.733738     9366.067033
# 75%       7236.794919     9597.220820    10931.085347    13277.182057
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       30.000000       30.000000       30.000000       30.000000
# mean     12479.575246    14283.979110    15617.896551    17214.310727
# std       5509.691411     5874.464896     6453.234827     7482.957960
# ...

# %%
europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
europe.T
# Out:
# country             Albania       Austria       Belgium  \
# gdpPercap_1952  1601.056136   6137.076492   8343.105127
# gdpPercap_1957  1942.284244   8842.598030   9714.960623
# gdpPercap_1962  2312.888958  10750.721110  10991.206760
# gdpPercap_1967  2760.196931  12834.602400  13149.041190
# gdpPercap_1972  3313.422188  16661.625600  16672.143560
# gdpPercap_1977  3533.003910  19749.422300  19117.974480
# gdpPercap_1982  3630.880722  21597.083620  20979.845890
# gdpPercap_1987  3738.932735  23687.826070  22525.563080
# gdpPercap_1992  2497.437901  27042.018680  25575.570690
# gdpPercap_1997  3193.054604  29095.920660  27561.196630
# gdpPercap_2002  4604.211737  32417.607690  30485.883750
# gdpPercap_2007  5937.029526  36126.492700  33692.605080
#
# country         Bosnia and Herzegovina      Bulgaria       Croatia  \
# gdpPercap_1952              973.533195   2444.286648   3119.236520
# gdpPercap_1957             1353.989176   3008.670727   4338.231617
# ...

# %%
eu.info
# Out:
# <bound method DataFrame.info of                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
europe.T.mean()
# Out:
# country
# Albania                    3255.366633
# Austria                   20411.916279
# Belgium                   19900.758072
# Bosnia and Herzegovina     3484.779069
# Bulgaria                   6384.055172
# Croatia                    9331.712346
# Czech Republic            13920.011379
# Denmark                   21671.824888
# Finland                   17473.722667
# France                    18833.570327
# Germany                   20556.684433
# Greece                    13969.036833
# Hungary                   10888.175654
# Iceland                   20531.422272
# Ireland                   15758.606238
# Italy                     16245.209006
# Montenegro                 7208.064560
# Netherlands               21748.852208
# Norway                    26747.306554
# Poland                     8416.553912
# Portugal                  11354.091927
# Romania                    7300.169974
# Serbia                     9305.049444
# Slovak Republic           10415.530689
# ...

# %%
europe.max(axis=1)
# Out:
# country
# Albania                    5937.029526
# Austria                   36126.492700
# Belgium                   33692.605080
# Bosnia and Herzegovina     7446.298803
# Bulgaria                  10680.792820
# Croatia                   14619.222720
# Czech Republic            22833.308510
# Denmark                   35278.418740
# Finland                   33207.084400
# France                    30470.016700
# Germany                   32170.374420
# Greece                    27538.411880
# Hungary                   18008.944440
# Iceland                   36180.789190
# Ireland                   40675.996350
# Italy                     28569.719700
# Montenegro                11732.510170
# Netherlands               36797.933320
# Norway                    49357.190170
# Poland                    15389.924680
# Portugal                  20509.647770
# Romania                   10808.475610
# Serbia                    15870.878510
# Slovak Republic           18678.314350
# ...

# %%
help(pandas)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
europe.loc[:,"gdpPercap_1957"]
# Out:
# country
# Albania                    1942.284244
# Austria                    8842.598030
# Belgium                    9714.960623
# Bosnia and Herzegovina     1353.989176
# Bulgaria                   3008.670727
# Croatia                    4338.231617
# Czech Republic             8256.343918
# Denmark                   11099.659350
# Finland                    7545.415386
# France                     8662.834898
# Germany                   10187.826650
# Greece                     4916.299889
# Hungary                    6040.180011
# Iceland                    9244.001412
# Ireland                    5599.077872
# Italy                      6248.656232
# Montenegro                 3682.259903
# Netherlands               11276.193440
# Norway                    11653.973040
# Poland                     4734.253019
# Portugal                   3774.571743
# Romania                    3943.370225
# Serbia                     4981.090891
# Slovak Republic            6093.262980
# ...
